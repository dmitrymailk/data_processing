# %%
import pandas as pd

# %%
dataset = pd.read_excel("./data/Анализ финансирования на 01.09.2022.xls", sheet_name="ФБ  ")
dataset.head(10)
# Out:
#   АНАЛИЗ ФИНАНСИРОВАНИЯ  за 2022 г. (по федеральным, пенсионным средствам)  \
# 0               по состоянию на  01 сентября 2022 г.
# 1                                                NaN
# 2                                             №№ п/п
# 3                                                NaN
# 4                                                NaN
# 5                                                  1
# 6                                                  2
# 7                                                  3
# 8                                                 10
# 9                                                 11
#
#                                           Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                       Наименование статей расходов        NaN        NaN
# 3                                             ВСЕГО:        NaN        NaN
# 4                     Итого из федерального бюджета:        NaN        NaN
# 5  Обеспечение мер социальной поддержки для лиц, ...          н        NaN
# 6  Оплата жилищно-коммунальных услуг отдельным ка...          н        NaN
# 7  Государственные единовременные пособия и ежеме...          н        NaN
# 8  Осуществление переданных органам государственн...          н        NaN
# 9  Выплата государственных пособий лицам, не подл...          н        NaN
#
#                                        Unnamed: 4  \
# 0                                             NaN
# 1                                             NaN
# 2  Уточненные бюджетные ассигнования на 2022 год
# 3                                     11593454.91
# 4                                     11592975.54
# 5                                        154777.2
# 6                                       1305097.5
# 7                                           154.7
# 8                                             NaN
# 9                                             NaN
#
#                                           Unnamed: 5     Unnamed: 6  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2  Уточненные лимиты бюджетных обязательств \nна ...  Кассовый план
# 3                                        11593454.91     8383110.41
# 4                                        11592975.54     8382630.94
# 5                                           154777.2       154777.2
# 6                                          1305097.5       873185.8
# 7                                              154.7          93.51
# 8                                                NaN              0
# 9                                                NaN            NaN
#
#             Unnamed: 7  Unnamed: 8
# 0                  NaN         NaN
# 1             тыс.руб.         NaN
# 2  Профинан-сировано           NaN
# 3           7661304.21         NaN
# 4           7660824.84         NaN
# 5            154684.17         NaN
# 6            852066.65         NaN
# 7                83.12         NaN
# 8                    0         NaN
# 9                  NaN         NaN

# %%
dataset.iloc[5, 1]
# Out:
# 'Обеспечение мер социальной поддержки для лиц, награжденных знаком "Почетный донор СССР", "Почетный донор России"'

# %%
columns = [
	"Наименование статей расходов",
	'Уточненные бюджетные ассигнования на 2022 год',
	'Уточненные лимиты бюджетных обязательств  на 2022 год',
	'Кассовый план',
	'Профинансировано  '
]

dataset.fillna(0, inplace=True)
flat_dataset = {column: [] for column in columns}

def append_flat_dataset(flat_dataset, columns, items):
	for column, item in zip(columns, items):
		flat_dataset[column].append(item)

for i in range(5, len(dataset)):
	item_0 = dataset.iloc[i, 1]
	item_1 = dataset.iloc[i, 4]
	item_2 = dataset.iloc[i, 5]
	item_3 = dataset.iloc[i, 6]
	item_4 = dataset.iloc[i, 7]

	items = [item_0, item_1, item_2, item_3, item_4]
	if not "Итого из средств пенсионного" in item_0:
		append_flat_dataset(flat_dataset, columns, items)

mock_data = [
	[
		"Осуществление ежемесячных выплат на детей в возрасте от трех до семи лет включительно за счет средств резервного фонда Правительства Российской Федерации",
		0,
		0,
		0,
		0
	]
]
append_flat_dataset(flat_dataset, columns, mock_data[0])

pd.DataFrame(data=flat_dataset).to_excel("./test.xlsx", index=False)

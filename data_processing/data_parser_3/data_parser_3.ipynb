# %%
import pandas as pd
import numpy as np

# %%
data_path = "./data/ПиР на 30.04.2022+Риски.xlsx"
sheet_name = "Здрав"

# %%
dataset = pd.read_excel(data_path, sheet_name='Культура', engine='openpyxl')
# sheet_name=sheet_name,

# %%
import openpyxl
wb = openpyxl.load_workbook("./data/ПиР на 30.04.2022+Риски.xlsx")
# print(wb.sheetnames)
sheet_names = wb.sheetnames
sheet_names.remove("РИСКИ")
sheet_names
# Out:
# ['Культура',
#  'Цифра',
#  'Образ-е',
#  'Жилье',
#  'Экология',
#  'МСП',
#  'Пр-ть',
#  'Здрав',
#  'Демография',
#  'БКД',
#  'Экспорт']

# %%
dataset.sheet_names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\programming\AI\volgograd\data_processing\data_parser_3\data_parser_3.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/programming/AI/volgograd/data_processing/data_parser_3/data_parser_3.ipynb#ch0000018?line=0'>1</a> dataset.sheet_names
#
# File d:\programming\AI\ai_env\lib\site-packages\pandas\core\generic.py:5465, in NDFrame.__getattr__(self, name)
#    <a href='file:///d%3A/programming/AI/ai_env/lib/site-packages/pandas/core/generic.py?line=5462'>5463</a> if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    <a href='file:///d%3A/programming/AI/ai_env/lib/site-packages/pandas/core/generic.py?line=5463'>5464</a>     return self[name]
# ...

# %%
dataset.head(10)
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2     Код РП        Тип        Вид
# 3        NaN        NaN        NaN
# 4          N        NaN          Ф
# 5         N1        NaN          Ф
# 6         N1  ОЗР\n(12)          Ф
# 7         N1          П          Ф
# 8         N1          П          Ф
# 9         N1          П          Ф
#
#                                           Unnamed: 3   Unnamed: 4  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2  Наименование\nрезультата(Р), показателя (П), з...  Тип\nед.изм
# 3                                                NaN          NaN
# 4                                 НП Здравоохранение          NaN
# 5  РП Первичная медико-санитарная помощь (Волгогр...          NaN
# 6  Гражданам, проживающим в населенных пунктах с ...            –
# ...

# %%
year_row_index = 0
for i in range(len(dataset)):
	row = dataset.iloc[i]
	row = map(str, list(row.values))
	str_row = "".join(row)
	if 'г.' in str_row:
		year_row_index = i
		break

# %%
sdfsdf

# %%
years_list = {}
for i in range(len(dataset.columns)):
	item = dataset.iloc[year_row_index, i]
	item = str(item)
	if 'г.' in item:
		years_list[item] = {
			"pos": [year_row_index, i]
		}

years_list
# Out:
# {'2019г.': {'pos': [2, 6]},
#  '2020г.': {'pos': [2, 9]},
#  '2021г.': {'pos': [2, 12]},
#  '2022г.': {'pos': [2, 15]}}

# %%
def row_stringify(row):
	row = map(str, list(row.values))
	str_row = "".join(row)
	return str_row

def coords(name):
	row_index = 0
	for i in range(len(dataset)):
		row = dataset.iloc[i]
		row_str = row_stringify(row)
		if name in row_str:
			row_index = i
			break
	col_index = 0
	for j in range(len(dataset.columns)):
		col = dataset.iloc[row_index, j]
		if name in str(col):
			col_index = j
			break
	
	return np.array([row_index, col_index])

# %%
def is_float_numeric(num):
	num = str(num)
	return num.replace(".", "").isnumeric()

def clean_number(num):
	if "(" in num:
		bracket_pos = num.index("(")
		num = num[:bracket_pos].strip().replace("\n", "").replace(",",".")
	return num

def clean_percent(num):
	num = str(num).replace("–", "").replace("_", "")
	if is_float_numeric(num):
		num = round(float(num), 1) * 100
	else:
		num = ""
	return num

code_pos = coords("Код РП")
some_type_pos = coords("Тип")
name_result_pos = coords("""Наименование
результата(Р), показателя (П), задачи(З), 
общественно-значимого результата (ОЗР)""") 
type_unit_pos = coords("""Тип
ед.изм""")
units_pos = coords("""Ед. 
изм.""")
some_plan_pos = coords("План")
some_sort_pos = coords("Вид")

next_year_1 = dataset.iloc[some_plan_pos[0]+1, some_plan_pos[1]]
next_year_2 = dataset.iloc[some_plan_pos[0]+1, some_plan_pos[1]+1]

type_start = coords("Вид")
general_type = (type_start[0]+2, type_start[1]+1)

general_type = dataset.iloc[general_type]
general_name = dataset.iloc[(type_start[0]+3, type_start[1]+1)]


new_dataset_columns = [
	"Отчетная дата",
	"Год",
	"Период",
	"Код РП",
	"Тип",
	"Вид",
	"Наименование национального проекта",
	"Наименование регионального проекта",
	"Наименование результата(Р), показателя (П), задачи(З), общественно-значимого результата (ОЗР)",
	"Тип ед.изм",
	"Ед. изм.",
	"План",
	"Факт",
	"%",
	"План значение",
	"Факт значение",
	"Not is empty"
]
flat_dataset = {name: [] for name in new_dataset_columns}

for i in range(7, len(dataset)):
	code = dataset.iloc[i, code_pos[1]]
	some_type = dataset.iloc[i, some_type_pos[1]]
	some_sort = dataset.iloc[i, some_sort_pos[1]]
	name_result = dataset.iloc[i, name_result_pos[1]].replace("\n", " ")
	type_unit = dataset.iloc[i, type_unit_pos[1]]
	units = dataset.iloc[i, units_pos[1]]

	if len(str(some_type)) == 0:
		general_name = dataset.iloc[i, type_start[1]+1]

	parsed_years = []

	# parse normal years
	for year in years_list:
		year_pos = years_list[year]['pos']
		year_plan = dataset.iloc[i, year_pos[1]] 
		year_fact = dataset.iloc[i, year_pos[1]+1] 
		year_percent = dataset.iloc[i, year_pos[1]+2]
		parsed_years.append([year, year_plan, year_fact, year_percent])

	# parse next years
	next_year_value_1 = dataset.iloc[i, some_plan_pos[1]]
	next_year_value_2 = dataset.iloc[i, some_plan_pos[1]+1] 

	parsed_years.append([next_year_1, next_year_value_1, None, None])
	parsed_years.append([next_year_2, next_year_value_2, None, None])

	
	row_str = "".join(map(str, [
		code, 
		some_type, 
		some_sort,
		name_result, 
		type_unit, 
		units,

	]))

	for year_item in parsed_years:
		is_empty = False
		year = str(year_item[0]).replace("г.", "")
		report_date = np.datetime64(
			pd.to_datetime(
				f"12/31/{year}", 
				format="%m/%d/%Y",
			), 
			'D'
		)
		# print(report_date)
		flat_dataset['Отчетная дата'].append(report_date)
		flat_dataset['Год'].append(int(year))
		flat_dataset['Период'].append(year)
		flat_dataset["Код РП"].append(code)
		flat_dataset["Тип"].append(some_type)
		flat_dataset["Вид"].append(some_sort)
		flat_dataset["Наименование национального проекта"].append(general_type)
		flat_dataset["Наименование регионального проекта"].append(general_name)
		flat_dataset["Наименование результата(Р), показателя (П), задачи(З), общественно-значимого результата (ОЗР)"].append(name_result)
		flat_dataset["Тип ед.изм"].append(type_unit)
		flat_dataset["Ед. изм."].append(units)
		flat_dataset["План"].append(year_item[1])
		flat_dataset["Факт"].append(year_item[2])
		
		year_percent = clean_percent(year_item[3])
		flat_dataset["%"].append(year_percent)
		
		plan_value = clean_number(str(year_item[1]))
		fact_value = clean_number(str(year_item[2]))
		# print(plan_value, plan_value.replace(".", "").isnumeric(), fact_value, fact_value.replace(".", "").isnumeric(),)
		
		if not is_float_numeric(plan_value) or "–" in plan_value or "–" in plan_value or 'None' in plan_value:
			is_empty = True
			plan_value = 0
		else:
			plan_value = float(plan_value)
		
		if not is_float_numeric(fact_value) or "–" in fact_value or "–" in fact_value or 'None' in fact_value:
			is_empty = True
			fact_value = 0
		else:
			fact_value = float(fact_value)
		flat_dataset["План значение"].append(plan_value)
		flat_dataset["Факт значение"].append(fact_value)

		year_str = "".join(map(str, year_item))
		result_str = row_str+year_str 
		if 'None' in result_str:
			is_empty = True
		
		is_empty_value = "да"
		if is_empty:
			is_empty_value = "нет"

		flat_dataset["Not is empty"].append(is_empty_value)

	# break

# %%
new_dataset = pd.DataFrame(data=flat_dataset)
new_dataset['Отчетная дата'] = new_dataset['Отчетная дата'].dt.date 
new_dataset.to_excel("./пир_тест_культура.xlsx", index=False, encoding='utf-8')

# %%
pd.read_excel("./data/ПиР на 30.04.2022+Риски.xlsx", sheet_name='Культура', engine="openpyxl").iloc[2, 6]
# Out:
# '2019г.'
